# %% [markdown]
# # Study 18 Fantasy Consistency
#
# ## Objective & Context
# Fantasy Optimization Study: Consistency Models
# Leverages Bowler Quality Rating and batting form to optimize lineups.
#
# ## Code Implementation
# The cell below uses the Midwicket API to calculate metrics and validate cricket analytics findings.

# %%
import midwicket as md
from midwicket.features import load_features

def main():
    print("=== Fantasy Model: Consistency ===")
    session = md.datasets.load_dataset("mlc")
    df_bqr = load_features("bowler_quality_rating", session)
    df_form = load_features("batting_form", session)
    print(df_bqr.head(3))
    print(df_form.head(3))

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Expected Output & Findings
# When executed, this notebook connects to the DuckDB-backed Midwicket analytical database engine, fetches the required dataset or pre-calculated features, runs aggregate SQL queries or metric loaders, and renders key findings.
